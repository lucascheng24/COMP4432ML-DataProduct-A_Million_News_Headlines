# %%
import numpy as np
import pandas as pd
from sklearn import metrics
from matplotlib import pyplot as plt

# %%
dataPath = '../processed_data/w2v_vec100_allRecords.csv'


df_headlines = pd.read_csv(dataPath)

df_headlines
# Out:
#                 0         1         2         3         4         5         6  \
# 0       -0.634602  2.367594  0.871591  2.359430 -2.965852  1.517270  0.751504
# 1       -0.378059 -0.452223  1.486985 -2.759467 -1.824923 -3.117064  2.082816
# 2        1.261505  2.702031 -0.149906  3.614451 -0.837862 -2.099598  4.797093
# 3        0.823092 -5.434307 -4.709791  3.259477 -1.074148  5.707097  5.959211
# 4       -3.721574 -5.655051 -4.546373 -0.489267 -0.764316  3.468202  4.450593
# ...           ...       ...       ...       ...       ...       ...       ...
# 1244179 -0.318331  0.729000  0.746162  3.532101  0.748576  5.302794  3.788126
# 1244180 -4.949424  5.286633 -5.216683 -2.490280  4.124398  7.596942  2.520643
# 1244181 -5.261847  0.455017  0.112804  3.050153  4.364166  0.753734 -1.335983
# 1244182 -2.081586  0.216300 -1.743438 -1.198245 -1.116413 -0.760701  0.243478
# 1244183 -5.403523  3.313066  2.468080  4.695230  1.882925 -1.465322 -4.090822
#
# ...

# %%
df_headlines.shape

size = len(df_headlines)

# %%
size
# Out:
# 1244184

# %%
num_size = round(size/10)

new_df = df_headlines.sample(n=num_size, random_state=4432)

new_df.shape
# Out:
# (124418, 100)

# %%
file_name = '../processed_data/w2v_vec100_'+ str(num_size) +'.csv'

# the file size is a little bit large, above 140MB
new_df.to_csv(file_name, sep=',', encoding='utf-8', index=False)
